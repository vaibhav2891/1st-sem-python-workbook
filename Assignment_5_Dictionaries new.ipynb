# %%
''''Name - vaibhav belekar
    Roll No - 20998
    College Name - AGC (SDBI)
    Class - F.Y. BSc Data Science
    Subject - Principles of Programming Language''''

# %% [markdown]
# <h2>Assignment 5 : DICTIONARY

# %% [markdown]
# ## Q1 Roll number dictionary

# %%
students={1:'A',2:'B',3:'C',4:'D',5:'E'}
print(students)
# Out:
# {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'E'}

# %% [markdown]
# ## Q2 Word frequency

# %%
s='hello world hello'
words=s.split()
freq={}
for w in words:
    freq[w]=freq.get(w,0)+1
print(freq)
# Out:
# {'hello': 2, 'world': 1}

# %% [markdown]
# ## Q3 Merge dictionaries

# %%
d1={'a':1}
d2={'b':2}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# ## Q4 Max value key

# %%
d={'a':10,'b':50,'c':30}
print(max(d, key=d.get))
# Out:
# b

# %% [markdown]
# ## Q5 Key exists

# %%
d={'a':1,'b':2}
print('a' in d)
# Out:
# True

# %% [markdown]
# <h2>SET B
#
# 1. Remove key safely

# %%
print(d.pop("x", "Not Found"))
# Out:
# Not Found

# %% [markdown]
# <h2>2. Sort by value

# %%
print(dict(sorted(d.items(), key=lambda x: x[1], reverse=True)))
# Out:
# {'b': 2, 'a': 1}

# %% [markdown]
# <h2>3. Dictionary from two lists

# %%
keys = [1,2,3]
vals = ['a','b','c']
print(dict(zip(keys, vals)))
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
keys = [1,2,3]

vals = ['a','b','c']

print(dict(zip(keys, vals)))
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
d = {'a':1, 'b':2, 'c':1}
val = 1
print([k for k,v in d.items() if v == val])
# Out:
# ['a', 'c']

# %%
2. Cubes dictionary

# %%
n = int(input())
print({i:i**3 for i in range(1, n+1)})
# Out:
#  23
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729, 10: 1000, 11: 1331, 12: 1728, 13: 2197, 14: 2744, 15: 3375, 16: 4096, 17: 4913, 18: 5832, 19: 6859, 20: 8000, 21: 9261, 22: 10648, 23: 12167}

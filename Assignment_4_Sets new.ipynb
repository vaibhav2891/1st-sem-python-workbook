# %%
''''Name - vaibhav belekar
    Roll No - 20998
    College Name - AGC (SDBI)
    Class - F.Y. BSc Data Science
    Subject - Principles of Programming Language''''

# %% [markdown]
# <h2>Assignment 4 : SET

# %% [markdown]
# ## Q1 Union, Intersection, Difference

# %%
a={1,2,3}
b={3,4,5}
print('Union:',a|b)
print('Intersection:',a&b)
print('Difference:',a-b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference: {1, 2}

# %% [markdown]
# ## Q2 Subset check

# %%
print({1,2}.issubset({1,2,3}))
# Out:
# True

# %% [markdown]
# ## Q3 Remove duplicates

# %%
lst=[1,2,2,3,3,4]
print(list(set(lst)))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## Q4 Elements in first not in second

# %%
print({1,2,3,4}-{3,4})
# Out:
# {1, 2}

# %% [markdown]
# ## Q5 Disjoint

# %%
print({1,2}.isdisjoint({3,4}))
# Out:
# True

# %% [markdown]
# <h2>SET B
#
# 1. Symmetric difference

# %%
set1={1,2,3,4}
set2={3,4,5,6}
result=set1^set2
print(result)
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# <h2>2. Add multiple elements

# %%
s = {1, 2}
s.update([3, 4, 5])
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# <h2>3. length and membership

# %%
print(len(s))
print(3 in s)
# Out:
# 5
# True

# %% [markdown]
# <h2>SET C
#
# Sentence operations

# %%
s1 = set(input().split())
s2 = set(input().split())
print("Common:", s1 & s2)
print("Only first:", s1 - s2)
print("Only second:", s2 - s1)
# Out:
#  kanda batata
#  batat
# Common: set()
# Only first: {'kanda', 'batata'}
# Only second: {'batat'}

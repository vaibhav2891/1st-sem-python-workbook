# %%
''''Name - vaibhav belekar
    Roll No - 20998
    College Name - AGC (SDBI)
    Class - F.Y. BSc Data Science
    Subject - Principles of Programming Language''''

# %% [markdown]
# <h2>Assignment 1 : BASIC PYTHON

# %% [markdown]
# <h2>Q1 Average of list

# %%
number=[10,20,30,40,50,60]
total=0
for n in list_num:
    total+=n
average = sum(list_num)/len(list_num)
print("average", average)
# Out:
# average 35.0

# %% [markdown]
# ## Q2 Duplicate check

# %%
nums=[32,10,45,90,45,6]
if len(nums)!=len(set(nums)):
    print('DUPLICATES')
else:
    print('ALL UNIQUE')
# Out:
# ALL UNIQUE

# %% [markdown]
# ## Q3 Range check

# %%
n=int(input('Enter number: '))
if 1<=n<=50:
    print('Ok')
else:
    print('Out of range')
# Out:
# Enter number:  4
# Ok

# %% [markdown]
# ## Q4 Sum of digits

# %%
n=int(input('Enter number: '))
s=0
while n>0:
    s+=n%10
    n//=10
print('Sum:',s)
# Out:
# Enter number:  34
# Sum: 7

# %% [markdown]
# ## Q5 Fibonacci

# %%
n=int(input('Terms: '))
a,b=0,1
print(a,b,end=' ')
for i in range(n-2):
    c=a+b
    print(c,end=' ')
    a,b=b,c
# Out:
# Terms:  4
# 0 1 1 2

# %% [markdown]
# ## Q6 Prime till n

# %%
n=int(input('Enter n: '))
for x in range(2,n+1):
    prime=True
    for i in range(2,x):
        if x%i==0:
            prime=False
    if prime:
        print(x)
# Out:
# Enter n:  5
# 2
# 3
# 5

# %% [markdown]
# ## Q7 Pattern

# %%
for i in range(4,0,-1):
    for j in range(1,i+1):
        print(j,end=' ')
    print()
# Out:
# 1 2 3 4
# 1 2 3
# 1 2
# 1

# %% [markdown]
# ## Q8 Reverse number

# %%
n=int(input('Enter number: '))
r=0
while n>0:
    r=r*10+n%10
    n//=10
print('Reverse:',r)
# Out:
# Enter number:  123
# Reverse: 321

# %% [markdown]
# ## Q9 Sequential Search

# %%
arr=[10,20,30,40,50]
t=int(input('Search: '))
found=False
for i in range(len(arr)):
    if arr[i]==t:
        print('Found at index',i)
        found=True
        break
if not found:
    print('Not found')
# Out:
# Search:  12
# Not found
